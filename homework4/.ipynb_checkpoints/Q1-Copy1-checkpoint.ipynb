# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import pygraphviz
from networkx.drawing.nx_agraph import to_agraph

# %% [markdown]
# ### Construct the chain graph

# %%
chain = nx.Graph()
for i in range(30):
    if i == 0:
        continue
    chain.add_weighted_edges_from([(i-1, i, 1)])

# %%
nx.draw(chain)
plt.draw()

# %% [markdown]
# ### Compute adjacency matrix, degree matrix, lapacian matrix and its eigenvectors

# %%
chain_A = nx.to_numpy_array(chain)

chain_D = np.zeros(np.shape(chain_A))
for i in range(len(chain_A)):
    chain_D[i][i] = np.sum(chain_A[i])

chain_L = chain_D - chain_A
chain_w, chain_v = np.linalg.eigh(chain_L)

# %%
print(chain_w)
# Out:
# [  3.72449519e-16   1.09562093e-02   4.37047985e-02   9.78869674e-02
#    1.72909085e-01   2.67949192e-01   3.81966011e-01   5.13710349e-01
#    6.61738787e-01   8.24429495e-01   1.00000000e+00   1.18652671e+00
#    1.38196601e+00   1.58417662e+00   1.79094307e+00   2.00000000e+00
#    2.20905693e+00   2.41582338e+00   2.61803399e+00   2.81347329e+00
#    3.00000000e+00   3.17557050e+00   3.33826121e+00   3.48628965e+00
#    3.61803399e+00   3.73205081e+00   3.82709092e+00   3.90211303e+00
#    3.95629520e+00   3.98904379e+00]

# %%
import seaborn as sns

# %%
# ax = sns.heatmap(np.reshape(chain_v[0], [1, 30]))
ax = sns.heatmap(np.reshape(chain_v[0], [1, 30]),cmap="BuPu", square=True)

# %%
print(chain_v[0])
# Out:
# [-0.18257419 -0.25784504 -0.25678445  0.25502003 -0.25255662 -0.24940098
#  -0.24556174  0.24104943 -0.23587642 -0.2300569  -0.2236068   0.21654381
#  -0.20888729 -0.20065822 -0.19187917  0.18257419 -0.17276878 -0.16248983
#  -0.1517655   0.14062519 -0.12909944 -0.11721984 -0.10501895  0.09253021
#  -0.07978784 -0.06682679 -0.05368257  0.04039121 -0.02698913 -0.01351309]

# %%
a = to_agraph(chain)
a.draw("sample.png", prog="neato", )

# %% [markdown]
# ### Create a lattice graph

# %%
lattice = nx.grid_graph([30, 30])

lattice_A = nx.to_numpy_array(lattice)

lattice_D = np.zeros(np.shape(lattice_A))

for i in range(len(lattice_A)):
    lattice_D[i][i] = np.sum(lattice_A[i])

lattice_L = lattice_D - lattice_A

lattice_w, lattice_v = np.linalg.eigh(lattice_L)

# %%
ax = sns.heatmap(np.reshape(lattice_v[1], [30, 30]), cmap="Greens")

# %%
pos = nx.spectral_layout(lattice)
nx.draw_networkx(lattice, pos=pos, node_color=lattice_v[1], font_size=0)

# %% [markdown]
# ### Reconstruct image using eigenvectors

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image

# %%
def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.299, 0.587, 0.114])

# %% [markdown]
# #### Load image and resize

# %%
image = Image.open('tiger.jpg')
image.thumbnail((150, 150), Image.ANTIALIAS)

plt.imshow(image)

# %%
image = np.array(image)

gray = np.dot(image[...,:3], [0.299, 0.587, 0.114])
# for i in range(150):
#     for j in range(150):
#         gray[i][j] =  0.2989 * image[i][j][0] + 0.5870 * image[i][j][1] + 0.1140 * image[i][j][2]

plt.imshow(gray, cmap='gray')
print(np.shape(gray))
# Out:
# (150, 150)

# %%
tiger_lattice = nx.grid_graph([150, 150])

tiger_lattice_A = nx.to_numpy_array(tiger_lattice)

tiger_lattice_D = np.zeros(np.shape(tiger_lattice_A))

for i in range(len(tiger_lattice_A)):
    tiger_lattice_D[i][i] = np.sum(tiger_lattice_A[i])

tiger_lattice_L = tiger_lattice_D - tiger_lattice_A

tiger_w, tiger_v = np.linalg.eigh(tiger_lattice_L)

# %%
np.shape(tiger_v)
